# %% [markdown]
# # Battle of the Neighborhoods Exploration

# %% [markdown]
# ## Table of Contents
#
# 1.  <a href="#item1">Foursquare API Search Function</a>
# 2.  <a href="#item2">Explore a Given Venue</a>
# 3.  <a href="#item3">Explore a User</a>
# 4.  <a href="#item4">Foursquare API Explore Function</a>
# 5.  <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: branca in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from folium==0.5.0) (2.10.3)
# Requirement already satisfied: requests in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from folium==0.5.0) (2.22.0)
# Requirement already satisfied: six in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from folium==0.5.0) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from requests->folium==0.5.0) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/bentre/opt/anaconda3/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.8)
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'SOJPKPZ015OYSMWNI33FDE45WPXV1TYNA41FTCGFHSNFPNRL' # your Foursquare ID
CLIENT_SECRET = 'UN4FY2DCKDANXOWXMDJOJWQR530BWZI3WVY2WYIMTUZQTOZX' # your Foursquare Secret
CODE = 'MYYSTTB2KGVIN4UJ34I0ZT0ZYHQBXVU3TZIIDT3STVXXSYPH#_=_'
ACCESS_TOKEN = 'IEWY5KTKBXWCB5VHGGC5ZGIRZ2F4BN3MUTNXOAWPW0RLA0GA' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SOJPKPZ015OYSMWNI33FDE45WPXV1TYNA41FTCGFHSNFPNRL
# CLIENT_SECRET:UN4FY2DCKDANXOWXMDJOJWQR530BWZI3WVY2WYIMTUZQTOZX

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = 'Berkeley, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.8708393 -122.2728639

# %% [markdown]
# <a id="item1"></a>

# %%
latitude = 37.871794
longitude = -122.259988

# %% [markdown]
# ## 1. Search for a specific venue category
#
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'Thai'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Thai .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SOJPKPZ015OYSMWNI33FDE45WPXV1TYNA41FTCGFHSNFPNRL&client_secret=UN4FY2DCKDANXOWXMDJOJWQR530BWZI3WVY2WYIMTUZQTOZX&ll=37.871794,-122.259988&oauth_token=IEWY5KTKBXWCB5VHGGC5ZGIRZ2F4BN3MUTNXOAWPW0RLA0GA&v=20180604&query=Thai&radius=2000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '601db2a6d0162b48e24df04a'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4a876707f964a5203a0420e3',
#     'name': 'Thai Basil',
#     'location': {'address': '2519 Durant Ave',
#      'crossStreet': 'at Telegraph Ave',
#      'lat': 37.86827098994154,
#      'lng': -122.25810522691953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.86827098994154,
#        'lng': -122.25810522691953}],
#      'distance': 425,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2519 Durant Ave (at Telegraph Ave)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2120165',
#      'url': 'https://www.grubhub.com/restaurant/thai-basil-cuisine-of-thailand-2519-durant-ave-berkeley/2120165?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2120165',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '54061097498ed729c0878cad',
#     'name': 'Imm Thai Street Food',
#     'location': {'address': '2068 University Ave',
#      'crossStreet': 'b/t Milvia St. & Shattuck Ave.',
#      'lat': 37.872006097358636,
#      'lng': -122.26909000849432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.872006097358636,
#        'lng': -122.26909000849432},
#       {'label': 'entrance', 'lat': 37.871928, 'lng': -122.269086}],
#      'distance': 800,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2068 University Ave (b/t Milvia St. & Shattuck Ave.)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4b0c99c3f964a520f53f23e3',
#     'name': 'Lucky House Thai',
#     'location': {'address': '2140 University Ave',
#      'crossStreet': 'at Shattuck',
#      'lat': 37.87215986318931,
#      'lng': -122.26731324777357,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87215986318931,
#        'lng': -122.26731324777357},
#       {'label': 'entrance', 'lat': 37.872163, 'lng': -122.267231}],
#      'distance': 644,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2140 University Ave (at Shattuck)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4bc90e66b6c49c74a3cf8d91',
#     'name': 'Chianglai Thai Cuisine',
#     'location': {'address': '2505 Hearst Ave',
#      'crossStreet': 'Euclid',
#      'lat': 37.875405,
#      'lng': -122.25976000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.875405,
#        'lng': -122.25976000000001},
#       {'label': 'entrance', 'lat': 37.87526, 'lng': -122.259738}],
#      'distance': 402,
#      'postalCode': '94709',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2505 Hearst Ave (Euclid)', 'Berkeley, CA 94709']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4af3a4e7f964a52008ef21e3',
#     'name': 'Thai Noodle II',
#     'location': {'address': '2426 Telegraph Ave',
#      'lat': 37.86642899939449,
#      'lng': -122.25880164348774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.86642899939449,
#        'lng': -122.25880164348774}],
#      'distance': 606,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2426 Telegraph Ave', 'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4af73795f964a520400722e3',
#     'name': 'Berkeley Thai House',
#     'location': {'address': '2511 Channing Way',
#      'crossStreet': 'at Telegraph Ave',
#      'lat': 37.86710482864535,
#      'lng': -122.25835824117937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.86710482864535,
#        'lng': -122.25835824117937},
#       {'label': 'entrance', 'lat': 37.867136, 'lng': -122.258314}],
#      'distance': 541,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2511 Channing Way (at Telegraph Ave)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '43334580f964a5200f281fe3',
#     'name': 'Tuk Tuk Thai Cafe',
#     'location': {'address': '2468 Shattuck Ave',
#      'crossStreet': 'at Haste',
#      'lat': 37.86452965430132,
#      'lng': -122.26754253779359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.86452965430132,
#        'lng': -122.26754253779359},
#       {'label': 'entrance', 'lat': 37.864425, 'lng': -122.267665}],
#      'distance': 1046,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2468 Shattuck Ave (at Haste)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '275147',
#      'url': 'https://www.grubhub.com/restaurant/tuk-tuk-thai-2468-shattuck-ave-berkeley/275147?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=275147',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4ada1f9cf964a520b41e21e3',
#     'name': 'Plearn Thai Kitchen',
#     'location': {'address': '2283 Shattuck Ave',
#      'crossStreet': 'btw Allston Way & Kittredge St',
#      'lat': 37.867865137233565,
#      'lng': -122.26772176913197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.867865137233565,
#        'lng': -122.26772176913197}],
#      'distance': 808,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2283 Shattuck Ave (btw Allston Way & Kittredge St)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4bba94261261d13a75dbea98',
#     'name': 'Plearn Thai Restaurant',
#     'location': {'address': '1923 University Ave',
#      'crossStreet': 'Martin Luther King Jr way',
#      'lat': 37.87178982702613,
#      'lng': -122.27239983449869,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87178982702613,
#        'lng': -122.27239983449869}],
#      'distance': 1090,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1923 University Ave (Martin Luther King Jr way)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4c68398f73851b8d0e02ba39',
#     'name': 'Bangkok Noodles & Thai BBQ',
#     'location': {'address': '1958 Shattuck Ave',
#      'lat': 37.87274962219312,
#      'lng': -122.2686168937319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87274962219312,
#        'lng': -122.2686168937319}],
#      'distance': 765,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1958 Shattuck Ave', 'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299434',
#      'url': 'https://www.grubhub.com/restaurant/bangkok-noodles-and-thai-bbq-1958-shattuck-ave-berkeley/299434?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299434',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4b455789f964a520ee0a26e3',
#     'name': 'Thai Delight Cuisine',
#     'location': {'address': '1700 Shattuck Ave',
#      'crossStreet': 'at Virginia',
#      'lat': 37.87642470801733,
#      'lng': -122.26896674845152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87642470801733,
#        'lng': -122.26896674845152}],
#      'distance': 942,
#      'postalCode': '94709',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1700 Shattuck Ave (at Virginia)',
#       'Berkeley, CA 94709']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '58454',
#      'url': 'https://www.grubhub.com/restaurant/thai-delight-cuisine-1700-shattuck-ave-berkeley/58454?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=58454',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4af1a18cf964a520b1e121e3',
#     'name': 'Dara Thai Lao Cuisine',
#     'location': {'address': '1549 Shattuck Ave',
#      'crossStreet': 'Cedar',
#      'lat': 37.87855199062824,
#      'lng': -122.26893917626485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87855199062824,
#        'lng': -122.26893917626485},
#       {'label': 'entrance', 'lat': 37.87859, 'lng': -122.268861}],
#      'distance': 1088,
#      'postalCode': '94709',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1549 Shattuck Ave (Cedar)', 'Berkeley, CA 94709']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4a30790df964a52073991fe3',
#     'name': 'Bangkok Thai Cuisine',
#     'location': {'address': '1459 University Ave',
#      'lat': 37.8702870340117,
#      'lng': -122.28348138547312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.8702870340117,
#        'lng': -122.28348138547312}],
#      'distance': 2071,
#      'postalCode': '94702',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1459 University Ave', 'Berkeley, CA 94702']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1212005',
#      'url': 'https://www.grubhub.com/restaurant/bangkok-thai-cuisine-1459-university-ave-berkeley/1212005?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1212005',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4a6a08cff964a5206ecc1fe3',
#     'name': 'Jasmine Thai',
#     'location': {'address': '1805 Euclid Ave',
#      'crossStreet': 'btw Hearst & Ridge',
#      'lat': 37.875780603130394,
#      'lng': -122.26017819038647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.875780603130394,
#        'lng': -122.26017819038647}],
#      'distance': 444,
#      'postalCode': '94709',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1805 Euclid Ave (btw Hearst & Ridge)',
#       'Berkeley, CA 94709']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4a736d25f964a5206adc1fe3',
#     'name': 'Gecko Gecko Thai California Eatery',
#     'location': {'address': '2101 Milvia St',
#      'crossStreet': 'at Addison',
#      'lat': 37.870885280281,
#      'lng': -122.27064928456188,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.870885280281,
#        'lng': -122.27064928456188}],
#      'distance': 942,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2101 Milvia St (at Addison)',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4f44766de4b027c578d10b49',
#     'name': "Thanu's Thai Kitchen",
#     'location': {'address': '2016 Shattuck Ave, Berkeley, CA 94704',
#      'lat': 37.87187576293945,
#      'lng': -122.26858520507812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.87187576293945,
#        'lng': -122.26858520507812}],
#      'distance': 755,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2016 Shattuck Ave, Berkeley, CA 94704',
#       'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4aef3205f964a52078d621e3',
#     'name': 'Thai E Sun',
#     'location': {'address': '1958 Shattuck Ave',
#      'lat': 37.872855833718724,
#      'lng': -122.268626018515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.872855833718724,
#        'lng': -122.268626018515}],
#      'distance': 768,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1958 Shattuck Ave', 'Berkeley, CA 94704']},
#     'categories': [],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4f3278ee19836c91c7db268c',
#     'name': 'Thai Garlic',
#     'location': {'address': '2042 University Ave',
#      'lat': 37.871646881103516,
#      'lng': -122.2696304321289,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 37.871854,
#        'lng': -122.269661},
#       {'label': 'display',
#        'lat': 37.871646881103516,
#        'lng': -122.2696304321289}],
#      'distance': 847,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2042 University Ave', 'Berkeley, CA 94704']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '5c94517475dcb7002c303dfd',
#     'name': 'Gai Barn Thai Soul Food',
#     'location': {'lat': 37.856399,
#      'lng': -122.252816,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.856399,
#        'lng': -122.252816}],
#      'distance': 1825,
#      'postalCode': '94705',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Berkeley, CA 94705']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1216883',
#      'url': 'https://www.grubhub.com/restaurant/gai-barn-thai-soul-food-2985-college-ave-berkeley/1216883?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1216883',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4f3269a519836c91c7d556ce',
#     'name': 'Mittaphab Lao Thai Restaurant',
#     'location': {'address': '1923 University Ave',
#      'lat': 37.871876,
#      'lng': -122.272374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.871876,
#        'lng': -122.272374},
#       {'label': 'entrance', 'lat': 37.871781, 'lng': -122.272362}],
#      'distance': 1088,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1923 University Ave', 'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4f323b8319836c91c7c339f8',
#     'name': "Palm's Thai Dinning",
#     'location': {'address': '1923 University Ave',
#      'lat': 37.871829986572266,
#      'lng': -122.27238464355469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.871829986572266,
#        'lng': -122.27238464355469}],
#      'distance': 1089,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1923 University Ave', 'Berkeley, CA 94704']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '5935d4c503369301d65df2ab',
#     'name': 'Nang Sida Thai Massage',
#     'location': {'lat': 37.863987,
#      'lng': -122.266549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.863987,
#        'lng': -122.266549}],
#      'distance': 1042,
#      'postalCode': '94704',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Berkeley, CA 94704']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '57350768498e53e0e8879105',
#     'name': 'Malai Thai Massage',
#     'location': {'address': '1819 University Ave',
#      'lat': 37.871659,
#      'lng': -122.274504,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.871659,
#        'lng': -122.274504}],
#      'distance': 1275,
#      'postalCode': '94703',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1819 University Ave', 'Berkeley, CA 94703']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4bcb4afa511f95216a23b1c7',
#     'name': 'Thai cultural center',
#     'location': {'address': '1911 Russell St',
#      'crossStreet': 'Martin luther king',
#      'lat': 37.855332,
#      'lng': -122.266205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.855332,
#        'lng': -122.266205}],
#      'distance': 1912,
#      'postalCode': '94703',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1911 Russell St (Martin luther king)',
#       'Berkeley, CA 94703']},
#     'categories': [],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4d5d86252a31a1cd8edb53f1',
#     'name': 'Dr Helen Thai DDS',
#     'location': {'address': 'telegraph ave',
#      'lat': 37.855028999999995,
#      'lng': -122.259424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.855028999999995,
#        'lng': -122.259424}],
#      'distance': 1866,
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['telegraph ave', 'Berkeley, CA']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '53a223cf498ef2f67e827903',
#     'name': 'Nine Thai Eatery',
#     'location': {'address': '1267 University Ave',
#      'lat': 37.869955,
#      'lng': -122.287421,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.869955,
#        'lng': -122.287421},
#       {'label': 'entrance', 'lat': 37.869858, 'lng': -122.287374}],
#      'distance': 2419,
#      'postalCode': '94702',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1267 University Ave', 'Berkeley, CA 94702']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4c45f2dcf1b5c9b60b1978ef',
#     'name': 'Thailand Grocery',
#     'location': {'address': '1704 University Ave',
#      'crossStreet': 'McGee',
#      'lat': 37.870731353759766,
#      'lng': -122.27728271484375,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 37.870878,
#        'lng': -122.277259},
#       {'label': 'display',
#        'lat': 37.870731353759766,
#        'lng': -122.27728271484375}],
#      'distance': 1524,
#      'postalCode': '94703',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1704 University Ave (McGee)',
#       'Berkeley, CA 94703']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False},
#    {'id': '4646efb9f964a52093461fe3',
#     'name': 'Wat Mongkolratanaram',
#     'location': {'address': '1911 Russell St',
#      'crossStreet': 'btw Martin Luther King Jr Way & Otis St',
#      'lat': 37.85661489167236,
#      'lng': -122.27080807785615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.85661489167236,
#        'lng': -122.27080807785615}],
#      'distance': 1938,
#      'postalCode': '94703',
#      'cc': 'US',
#      'city': 'Berkeley',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1911 Russell St (btw Martin Luther King Jr Way & Otis St)',
#       'Berkeley, CA 94703']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612559014',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a _pandas_ dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /Users/bentre/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                    name  \
# 0  4a876707f964a5203a0420e3              Thai Basil
# 1  54061097498ed729c0878cad    Imm Thai Street Food
# 2  4b0c99c3f964a520f53f23e3        Lucky House Thai
# 3  4bc90e66b6c49c74a3cf8d91  Chianglai Thai Cuisine
# 4  4af3a4e7f964a52008ef21e3          Thai Noodle II
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1612559014    False
# 1  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1612559014    False
# 2  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1612559014    False
# 3  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1612559014    False
# 4  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1612559014    False
#
#       location.address            location.crossStreet  location.lat  \
# 0      2519 Durant Ave                at Telegraph Ave     37.868271
# 1  2068 University Ave  b/t Milvia St. & Shattuck Ave.     37.872006
# 2  2140 University Ave                     at Shattuck     37.872160
# 3      2505 Hearst Ave                          Euclid     37.875405
# 4   2426 Telegraph Ave                             NaN     37.866429
#
#    location.lng                            location.labeledLatLngs  ...  \
# 0   -122.258105  [{'label': 'display', 'lat': 37.86827098994154...  ...
# 1   -122.269090  [{'label': 'display', 'lat': 37.87200609735863...  ...
# 2   -122.267313  [{'label': 'display', 'lat': 37.87215986318931...  ...
# 3   -122.259760  [{'label': 'display', 'lat': 37.875405, 'lng':...  ...
# 4   -122.258802  [{'label': 'display', 'lat': 37.86642899939449...  ...
#
#    location.city location.state location.country  \
# 0       Berkeley             CA    United States
# 1       Berkeley             CA    United States
# 2       Berkeley             CA    United States
# 3       Berkeley             CA    United States
# 4       Berkeley             CA    United States
#
#                            location.formattedAddress delivery.id  \
# 0  [2519 Durant Ave (at Telegraph Ave), Berkeley,...     2120165
# 1  [2068 University Ave (b/t Milvia St. & Shattuc...         NaN
# 2  [2140 University Ave (at Shattuck), Berkeley, ...         NaN
# 3     [2505 Hearst Ave (Euclid), Berkeley, CA 94709]         NaN
# 4           [2426 Telegraph Ave, Berkeley, CA 94704]         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0  https://www.grubhub.com/restaurant/thai-basil-...                grubhub
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                delivery.provider.icon.name
# 0  /delivery_provider_grubhub_20180129.png
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name        categories  \
# 0                           Thai Basil   Thai Restaurant
# 1                 Imm Thai Street Food   Thai Restaurant
# 2                     Lucky House Thai   Thai Restaurant
# 3               Chianglai Thai Cuisine   Thai Restaurant
# 4                       Thai Noodle II   Thai Restaurant
# 5                  Berkeley Thai House   Thai Restaurant
# 6                    Tuk Tuk Thai Cafe   Thai Restaurant
# 7                  Plearn Thai Kitchen   Thai Restaurant
# 8               Plearn Thai Restaurant   Thai Restaurant
# 9           Bangkok Noodles & Thai BBQ   Thai Restaurant
# 10                Thai Delight Cuisine   Thai Restaurant
# 11               Dara Thai Lao Cuisine   Thai Restaurant
# 12                Bangkok Thai Cuisine   Thai Restaurant
# 13                        Jasmine Thai   Thai Restaurant
# 14  Gecko Gecko Thai California Eatery   Thai Restaurant
# 15                Thanu's Thai Kitchen   Thai Restaurant
# 16                          Thai E Sun              None
# 17                         Thai Garlic              Food
# 18             Gai Barn Thai Soul Food   Thai Restaurant
# 19       Mittaphab Lao Thai Restaurant   Thai Restaurant
# 20                 Palm's Thai Dinning   Thai Restaurant
# 21              Nang Sida Thai Massage    Massage Studio
# 22                  Malai Thai Massage    Massage Studio
# 23                Thai cultural center              None
# 24                   Dr Helen Thai DDS  Dentist's Office
# 25                    Nine Thai Eatery   Thai Restaurant
# 26                    Thailand Grocery     Grocery Store
# 27                Wat Mongkolratanaram   Thai Restaurant
#
#                                   address  \
# 0                         2519 Durant Ave
# 1                     2068 University Ave
# 2                     2140 University Ave
# 3                         2505 Hearst Ave
# 4                      2426 Telegraph Ave
# 5                       2511 Channing Way
# 6                       2468 Shattuck Ave
# 7                       2283 Shattuck Ave
# 8                     1923 University Ave
# 9                       1958 Shattuck Ave
# 10                      1700 Shattuck Ave
# 11                      1549 Shattuck Ave
# 12                    1459 University Ave
# 13                        1805 Euclid Ave
# 14                         2101 Milvia St
# 15  2016 Shattuck Ave, Berkeley, CA 94704
# 16                      1958 Shattuck Ave
# 17                    2042 University Ave
# 18                                    NaN
# 19                    1923 University Ave
# 20                    1923 University Ave
# 21                                    NaN
# 22                    1819 University Ave
# 23                        1911 Russell St
# 24                          telegraph ave
# 25                    1267 University Ave
# 26                    1704 University Ave
# 27                        1911 Russell St
#
#                                 crossStreet        lat         lng  \
# 0                          at Telegraph Ave  37.868271 -122.258105
# 1            b/t Milvia St. & Shattuck Ave.  37.872006 -122.269090
# 2                               at Shattuck  37.872160 -122.267313
# 3                                    Euclid  37.875405 -122.259760
# 4                                       NaN  37.866429 -122.258802
# 5                          at Telegraph Ave  37.867105 -122.258358
# 6                                  at Haste  37.864530 -122.267543
# 7            btw Allston Way & Kittredge St  37.867865 -122.267722
# 8                 Martin Luther King Jr way  37.871790 -122.272400
# 9                                       NaN  37.872750 -122.268617
# 10                              at Virginia  37.876425 -122.268967
# 11                                    Cedar  37.878552 -122.268939
# 12                                      NaN  37.870287 -122.283481
# 13                       btw Hearst & Ridge  37.875781 -122.260178
# 14                               at Addison  37.870885 -122.270649
# 15                                      NaN  37.871876 -122.268585
# 16                                      NaN  37.872856 -122.268626
# 17                                      NaN  37.871647 -122.269630
# 18                                      NaN  37.856399 -122.252816
# 19                                      NaN  37.871876 -122.272374
# 20                                      NaN  37.871830 -122.272385
# 21                                      NaN  37.863987 -122.266549
# 22                                      NaN  37.871659 -122.274504
# 23                       Martin luther king  37.855332 -122.266205
# 24                                      NaN  37.855029 -122.259424
# 25                                      NaN  37.869955 -122.287421
# 26                                    McGee  37.870731 -122.277283
# 27  btw Martin Luther King Jr Way & Otis St  37.856615 -122.270808
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 37.86827098994154...       425      94704
# 1   [{'label': 'display', 'lat': 37.87200609735863...       800      94704
# 2   [{'label': 'display', 'lat': 37.87215986318931...       644      94704
# 3   [{'label': 'display', 'lat': 37.875405, 'lng':...       402      94709
# 4   [{'label': 'display', 'lat': 37.86642899939449...       606      94704
# 5   [{'label': 'display', 'lat': 37.86710482864535...       541      94704
# 6   [{'label': 'display', 'lat': 37.86452965430132...      1046      94704
# 7   [{'label': 'display', 'lat': 37.86786513723356...       808      94704
# 8   [{'label': 'display', 'lat': 37.87178982702613...      1090      94704
# 9   [{'label': 'display', 'lat': 37.87274962219312...       765      94704
# 10  [{'label': 'display', 'lat': 37.87642470801733...       942      94709
# 11  [{'label': 'display', 'lat': 37.87855199062824...      1088      94709
# 12  [{'label': 'display', 'lat': 37.8702870340117,...      2071      94702
# 13  [{'label': 'display', 'lat': 37.87578060313039...       444      94709
# 14  [{'label': 'display', 'lat': 37.870885280281, ...       942      94704
# 15  [{'label': 'display', 'lat': 37.87187576293945...       755      94704
# 16  [{'label': 'display', 'lat': 37.87285583371872...       768      94704
# 17  [{'label': 'entrance', 'lat': 37.871854, 'lng'...       847      94704
# 18  [{'label': 'display', 'lat': 37.856399, 'lng':...      1825      94705
# 19  [{'label': 'display', 'lat': 37.871876, 'lng':...      1088      94704
# 20  [{'label': 'display', 'lat': 37.87182998657226...      1089      94704
# 21  [{'label': 'display', 'lat': 37.863987, 'lng':...      1042      94704
# 22  [{'label': 'display', 'lat': 37.871659, 'lng':...      1275      94703
# 23  [{'label': 'display', 'lat': 37.855332, 'lng':...      1912      94703
# 24  [{'label': 'display', 'lat': 37.85502899999999...      1866        NaN
# 25  [{'label': 'display', 'lat': 37.869955, 'lng':...      2419      94702
# 26  [{'label': 'entrance', 'lat': 37.870878, 'lng'...      1524      94703
# 27  [{'label': 'display', 'lat': 37.85661489167236...      1938      94703
#
#     cc      city state        country  \
# 0   US  Berkeley    CA  United States
# 1   US  Berkeley    CA  United States
# 2   US  Berkeley    CA  United States
# 3   US  Berkeley    CA  United States
# 4   US  Berkeley    CA  United States
# 5   US  Berkeley    CA  United States
# 6   US  Berkeley    CA  United States
# 7   US  Berkeley    CA  United States
# 8   US  Berkeley    CA  United States
# 9   US  Berkeley    CA  United States
# 10  US  Berkeley    CA  United States
# 11  US  Berkeley    CA  United States
# 12  US  Berkeley    CA  United States
# 13  US  Berkeley    CA  United States
# 14  US  Berkeley    CA  United States
# 15  US  Berkeley    CA  United States
# 16  US  Berkeley    CA  United States
# 17  US  Berkeley    CA  United States
# 18  US  Berkeley    CA  United States
# 19  US  Berkeley    CA  United States
# 20  US  Berkeley    CA  United States
# 21  US  Berkeley    CA  United States
# 22  US  Berkeley    CA  United States
# 23  US  Berkeley    CA  United States
# 24  US  Berkeley    CA  United States
# 25  US  Berkeley    CA  United States
# 26  US  Berkeley    CA  United States
# 27  US  Berkeley    CA  United States
#
#                                      formattedAddress  \
# 0   [2519 Durant Ave (at Telegraph Ave), Berkeley,...
# 1   [2068 University Ave (b/t Milvia St. & Shattuc...
# 2   [2140 University Ave (at Shattuck), Berkeley, ...
# 3      [2505 Hearst Ave (Euclid), Berkeley, CA 94709]
# 4            [2426 Telegraph Ave, Berkeley, CA 94704]
# 5   [2511 Channing Way (at Telegraph Ave), Berkele...
# 6   [2468 Shattuck Ave (at Haste), Berkeley, CA 94...
# 7   [2283 Shattuck Ave (btw Allston Way & Kittredg...
# 8   [1923 University Ave (Martin Luther King Jr wa...
# 9             [1958 Shattuck Ave, Berkeley, CA 94704]
# 10  [1700 Shattuck Ave (at Virginia), Berkeley, CA...
# 11    [1549 Shattuck Ave (Cedar), Berkeley, CA 94709]
# 12          [1459 University Ave, Berkeley, CA 94702]
# 13  [1805 Euclid Ave (btw Hearst & Ridge), Berkele...
# 14  [2101 Milvia St (at Addison), Berkeley, CA 94704]
# 15  [2016 Shattuck Ave, Berkeley, CA 94704, Berkel...
# 16            [1958 Shattuck Ave, Berkeley, CA 94704]
# 17          [2042 University Ave, Berkeley, CA 94704]
# 18                               [Berkeley, CA 94705]
# 19          [1923 University Ave, Berkeley, CA 94704]
# 20          [1923 University Ave, Berkeley, CA 94704]
# 21                               [Berkeley, CA 94704]
# 22          [1819 University Ave, Berkeley, CA 94703]
# 23  [1911 Russell St (Martin luther king), Berkele...
# 24                      [telegraph ave, Berkeley, CA]
# 25          [1267 University Ave, Berkeley, CA 94702]
# 26  [1704 University Ave (McGee), Berkeley, CA 94703]
# 27  [1911 Russell St (btw Martin Luther King Jr Wa...
#
#                           id
# 0   4a876707f964a5203a0420e3
# 1   54061097498ed729c0878cad
# 2   4b0c99c3f964a520f53f23e3
# 3   4bc90e66b6c49c74a3cf8d91
# 4   4af3a4e7f964a52008ef21e3
# 5   4af73795f964a520400722e3
# 6   43334580f964a5200f281fe3
# 7   4ada1f9cf964a520b41e21e3
# 8   4bba94261261d13a75dbea98
# 9   4c68398f73851b8d0e02ba39
# 10  4b455789f964a520ee0a26e3
# 11  4af1a18cf964a520b1e121e3
# 12  4a30790df964a52073991fe3
# 13  4a6a08cff964a5206ecc1fe3
# 14  4a736d25f964a5206adc1fe3
# 15  4f44766de4b027c578d10b49
# 16  4aef3205f964a52078d621e3
# 17  4f3278ee19836c91c7db268c
# 18  5c94517475dcb7002c303dfd
# 19  4f3269a519836c91c7d556ce
# 20  4f323b8319836c91c7c339f8
# 21  5935d4c503369301d65df2ab
# 22  57350768498e53e0e8879105
# 23  4bcb4afa511f95216a23b1c7
# 24  4d5d86252a31a1cd8edb53f1
# 25  53a223cf498ef2f67e827903
# 26  4c45f2dcf1b5c9b60b1978ef
# 27  4646efb9f964a52093461fe3

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                             Thai Basil
# 1                   Imm Thai Street Food
# 2                       Lucky House Thai
# 3                 Chianglai Thai Cuisine
# 4                         Thai Noodle II
# 5                    Berkeley Thai House
# 6                      Tuk Tuk Thai Cafe
# 7                    Plearn Thai Kitchen
# 8                 Plearn Thai Restaurant
# 9             Bangkok Noodles & Thai BBQ
# 10                  Thai Delight Cuisine
# 11                 Dara Thai Lao Cuisine
# 12                  Bangkok Thai Cuisine
# 13                          Jasmine Thai
# 14    Gecko Gecko Thai California Eatery
# 15                  Thanu's Thai Kitchen
# 16                            Thai E Sun
# 17                           Thai Garlic
# 18               Gai Barn Thai Soul Food
# 19         Mittaphab Lao Thai Restaurant
# 20                   Palm's Thai Dinning
# 21                Nang Sida Thai Massage
# 22                    Malai Thai Massage
# 23                  Thai cultural center
# 24                     Dr Helen Thai DDS
# 25                      Nine Thai Eatery
# 26                      Thailand Grocery
# 27                  Wat Mongkolratanaram
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Berkeley, CA',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_328c71cb07214db1a1307b34ce969039%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_328c71cb07214db1a1307b34ce969039%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_328c71cb07214db1a1307b34ce969039%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_328c71cb07214db1a1307b34ce969039%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.871794%2C-122.259988%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=SOJPKPZ015OYSMWNI33FDE45WPXV1TYNA41FTCGFHSNFPNRL&client_secret=UN4FY2DCKDANXOWXMDJOJWQR530BWZI3WVY2WYIMTUZQTOZX&oauth_token=IEWY5KTKBXWCB5VHGGC5ZGIRZ2F4BN3MUTNXOAWPW0RLA0GA&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4fa862b3e4b0ebff2f749f06',
#  'name': "Harry's Italian Pizza Bar",
#  'contact': {'phone': '2126081007', 'formattedPhone': '(212) 608-1007'},
#  'location': {'address': '225 Murray St',
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351},
#    {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}],
#   'postalCode': '10282',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St', 'New York, NY 10282']},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'shortName': 'Pizza',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 56},
#  'url': 'http://harrysitalian.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 120,
#   'groups': [{'type': 'others', 'count': 120, 'items': []}],
#   'summary': '120 Likes'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'rating': 6.9,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 211,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 146,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 146,
#     'items': [{'id': '4fad980de4b091b4626c3633',
#       'createdAt': 1336776717,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'width': 480,
#       'height': 640,
#       'user': {'id': '13676709',
#        'firstName': 'Leony',
#        'lastName': 'Naciri',
#        'gender': 'none',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1336435379,
#  'tips': {'count': 56,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 56,
#     'items': [{'id': '53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others',
#          'count': 4,
#          'items': [{'id': '87587879',
#            'firstName': 'Diane',
#            'lastName': 'Danneels',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'id': '87591341',
#            'firstName': 'Tim',
#            'lastName': 'Sheehan',
#            'gender': 'male',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'id': '87473404',
#            'firstName': 'TenantKing.com',
#            'gender': 'none',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}]}],
#        'summary': '4 likes'},
#       'like': False,
#       'logView': True,
#       'agreeCount': 3,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '87473404',
#        'firstName': 'TenantKing.com',
#        'gender': 'none',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}}]}]},
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 54,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 54,
#     'items': [{'id': '4fa32fd0e4b04193744746b1',
#       'name': 'Manhattan Haunts',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '24592223',
#        'firstName': 'Becca',
#        'lastName': 'McArthur',
#        'gender': 'female',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'createdAt': 1336094672,
#       'updatedAt': 1380845377,
#       'photo': {'id': '4e8cc9461081e3b3544e12e5',
#        'createdAt': 1317849414,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'width': 492,
#        'height': 330,
#        'user': {'id': '742542',
#         'firstName': 'Time Out New York',
#         'gender': 'none',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public'},
#       'followers': {'count': 22},
#       'listItems': {'count': 187,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1342934485}]}},
#      {'id': '4fae817be4b085f6b2a74d19',
#       'name': 'USA NYC MAN FiDi',
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'type': 'others',
#       'user': {'id': '12113441',
#        'firstName': 'Kino',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'createdAt': 1336836475,
#       'updatedAt': 1556754919,
#       'photo': {'id': '55984992498e13ba75e353bb',
#        'createdAt': 1436043666,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'width': 540,
#        'height': 960,
#        'user': {'id': '12113441',
#         'firstName': 'Kino',
#         'gender': 'male',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 20},
#       'listItems': {'count': 273,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1373909433}]}}]}]},
#  'hours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Thu',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]}]},
#  'bestPhoto': {'id': '4fad980de4b091b4626c3633',
#   'createdAt': 1336776717,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'width': 480,
#   'height': 640,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.9

# %% [markdown]
# That is not a very good rating. Let's check the rating of the second closest Italian restaurant.

# %%
venue_id = '4f3232e219836c91c7bfde94' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Since this restaurant has no ratings, let's check the third restaurant.

# %%
venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.3

# %% [markdown]
# Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# ## 4. Explore a location
#
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitude = 37.871794
longitude = -122.259988

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=SOJPKPZ015OYSMWNI33FDE45WPXV1TYNA41FTCGFHSNFPNRL&client_secret=UN4FY2DCKDANXOWXMDJOJWQR530BWZI3WVY2WYIMTUZQTOZX&ll=37.871794,-122.259988&v=20180604&radius=2000&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ba106c4f964a520579037e3',
#   'name': 'Campanile (Sather Tower)',
#   'location': {'address': 'Campanile Esplanade',
#    'lat': 37.87193214890736,
#    'lng': -122.2580968508397,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 37.87193214890736,
#      'lng': -122.2580968508397}],
#    'distance': 166,
#    'postalCode': '94709',
#    'cc': 'US',
#    'city': 'Berkeley',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['Campanile Esplanade',
#     'Berkeley, CA 94709',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d165941735',
#     'name': 'Scenic Lookout',
#     'pluralName': 'Scenic Lookouts',
#     'shortName': 'Scenic Lookout',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4ba106c4f964a520579037e3-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /Users/bentre/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                     name             categories  \
# 0               Campanile (Sather Tower)         Scenic Lookout
# 1                        Zellerbach Hall        College Theater
# 2                       Woo Hon Fai Hall  Performing Arts Venue
# 3                     Hertz Concert Hall           Concert Hall
# 4  William Randolph Hearst Greek Theatre           Amphitheater
# 5                             Cinnaholic                 Bakery
# 6                                 BAMPFA             Art Museum
# 7                                Top Dog          Hot Dog Joint
# 8              Amazon@ASUC Student Union         Shipping Store
# 9         The pool at Berkeley City Club                   Pool
#
#                                         address        lat         lng  \
# 0                           Campanile Esplanade  37.871932 -122.258097
# 1                           101 Zellerbach Hall  37.869167 -122.260498
# 2                               2625 Durant Ave  37.868679 -122.255867
# 3                                  U C Berkeley  37.870978 -122.255775
# 4                                2001 Gayley Rd  37.873748 -122.254245
# 5                            2132 Oxford Street  37.870304 -122.266084
# 6                                2155 Center St  37.870856 -122.266455
# 7                               2534 Durant Ave  37.867986 -122.257397
# 8  MLK Student Union 2495 Bancroft Way Room 235  37.869297 -122.259387
# 9                               2315 Durant Ave  37.867612 -122.262543
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 37.87193214890736...       166      94709  US
# 1  [{'label': 'display', 'lat': 37.86916713570641...       295      94720  US
# 2  [{'label': 'display', 'lat': 37.86867904663086...       501      94720  US
# 3  [{'label': 'display', 'lat': 37.87097799864652...       381      94720  US
# 4  [{'label': 'display', 'lat': 37.87374820090017...       549      94720  US
# 5  [{'label': 'entrance', 'lat': 37.870258, 'lng'...       560      94704  US
# 6  [{'label': 'display', 'lat': 37.87085586060765...       577      94704  US
# 7  [{'label': 'display', 'lat': 37.86798622781440...       481      94704  US
# 8  [{'label': 'display', 'lat': 37.86929705907425...       282      94720  US
# 9  [{'label': 'display', 'lat': 37.86761217476545...       516      94704  US
#
#        city state        country  \
# 0  Berkeley    CA  United States
# 1  Berkeley    CA  United States
# 2  Berkeley    CA  United States
# 3  Berkeley    CA  United States
# 4  Berkeley    CA  United States
# 5  Berkeley    CA  United States
# 6  Berkeley    CA  United States
# 7  Berkeley    CA  United States
# 8  Berkeley    CA  United States
# 9  Berkeley    CA  United States
#
#                                     formattedAddress  \
# 0  [Campanile Esplanade, Berkeley, CA 94709, Unit...
# 1  [101 Zellerbach Hall (at Telegraph Ave.), Berk...
# 2  [2625 Durant Ave, Berkeley, CA 94720, United S...
# 3  [U C Berkeley (at UC Berkeley), Berkeley, CA 9...
# 4  [2001 Gayley Rd, Berkeley, CA 94720, United St...
# 5  [2132 Oxford Street (at Center St), Berkeley, ...
# 6  [2155 Center St (at Oxford St), Berkeley, CA 9...
# 7  [2534 Durant Ave (btwn Telegraph & Bowditch St...
# 8  [MLK Student Union 2495 Bancroft Way Room 235,...
# 9  [2315 Durant Ave, Berkeley, CA 94704, United S...
#
#                     crossStreet neighborhood                        id
# 0                           NaN          NaN  4ba106c4f964a520579037e3
# 1             at Telegraph Ave.          NaN  44169375f964a52006311fe3
# 2                           NaN          NaN  590d8f5d018cbb785f3b6578
# 3                at UC Berkeley          NaN  4aea4877f964a520bcba21e3
# 4                           NaN          NaN  4c0082bd34ccc928bec5e1cd
# 5                  at Center St          NaN  4c40b646d691c9b6c0a08b0a
# 6                  at Oxford St          NaN  56aad9ff498e06046ff5e01b
# 7  btwn Telegraph & Bowditch St          NaN  4a7414a6f964a520b8dd1fe3
# 8                           NaN          NaN  56c60eadcd10fb359a0a1fa6
# 9                           NaN          NaN  5aa39ae5838e59757f4509c3

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_e846708838f74f80a46ab42c11a5b4f0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e846708838f74f80a46ab42c11a5b4f0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e846708838f74f80a46ab42c11a5b4f0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_e846708838f74f80a46ab42c11a5b4f0%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B37.871794%2C-122.259988%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
#
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around Ecco, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Ecco.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '601db2aa0046ef47fed9b8b3'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
